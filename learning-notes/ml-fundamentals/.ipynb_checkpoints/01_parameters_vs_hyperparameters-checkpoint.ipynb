# %% [markdown]
# ## Concept name
# One line — what is this in plain English

# %% [markdown]
# ## How it actually works
# 3-5 sentences. No jargon.

# %% [markdown]
# ## Where it breaks or gets dangerous
# Edge cases, failure modes

# %%
# Minimal code example if applicable

# %% [markdown]
# ## My D365 analogy
# How does this map to something I already know from ERP

# %% [markdown]
# ## LinkedIn post idea
# One sentence — raw idea for a post based on this concept
